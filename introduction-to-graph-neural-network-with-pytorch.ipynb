# %% [markdown]
# **Introduction to Graph data**
#
# Graphs can be seen as a system or language for modeling systems that are complex and linked together.
# A graph is a data type that is modelled as a set of objects which can be represented as a node or vertex and their relationships which is called edges. A graph data can also be seen as a network data where there are points connected together.
#
# **A node(vertex)** of a graph is point in a graph while **an edge** is a component that joins edges together in a graph. Graphs can be used to represent data from a lot of domains like biology, physics, social science, chemistry and others.
#
# ![graph.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Graph classification**
#
# Graphs can be classified into different categories **directed/undirected graphs**, **weighted/binary graphs** and **homogenous/heterogenous graphs**.
#
#
#
# *   **Directed/Undirected graphs**: Directed graphs are the ones that all the edges have directtions while in undirected graphs, the edges are does not have directions
# *   **Weighted/Binary graphs**: Weighted graphs is a type of graph that each of the edges are assigned with a value while binary graphs are the ones that the edges does not have an assigned value.
# *   **Homogenous/Heterogenous graphs**: Homogenous graphs are the ones that all the nodes and/or edges are of the same type (e.g. friendship graph) while heterogenous graphs are graphs where the nodes and/or edges are of different types (e.g. knowledge graph).
#
#
# **Traditional graph analysis** methods requires using searching algorithms, clustering spanning tree algorithms and so on. A major downside to using these methods for analysis of graph data is that you require a prior knowledge of the graph to be able to apply these algorithms.
#
# Based on the structure of the graph data, traditional machine learning system will not be able to properly interprete the graph data and thus the advent of the **Graph Neural Network (GNN)**. Graph neural network is a domain of deep learning that is mostly concerned with deep learning operations on graph datasets.
#
# **Application of Machine learning in Graphs**
#
# 1. Protein folding for drug analysis
# 2. Recommender systems
# 3. Drug side effect prediction
# 4. Traffic predictions
# 5. Drug discovery
# 6. Molecule generation
# 7. Physics simulation

# %% [markdown]
# **Exploring graph with Pytorch Geometric**
#
# In this notebook we will explore graph and graph neural network using PyTorch Geometric (PyG). We will start by importing and installing the needed packages.

# %%
#install required packages
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)
#ensure that the PyTorch and the PyG are the same version

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
# Out:
# 2.1.0+cu121
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-win_amd64.whl.metadata (5.4 kB)
# Downloading ninja-1.11.1.1-py2.py3-none-win_amd64.whl (312 kB)
#    ---------------------------------------- 0.0/313.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/313.0 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/313.0 kB 487.6 kB/s eta 0:00:01
#    -------------------------------- ------- 256.0/313.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 313.0/313.0 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1.1
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [260 lines of output]
#   running bdist_wheel
#   D:\programs\python311\Lib\site-packages\torch\utils\cpp_extension.py:502: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#     warnings.warn(msg.format('we could not find ninja.'))
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\add.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\bandwidth.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\cat.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\coalesce.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\convert.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\diag.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\eye.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\index_select.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\masked_select.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\matmul.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\metis.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\mul.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\narrow.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\permute.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\reduce.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\rw.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\saint.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\sample.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\select.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\spadd.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\spmm.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\spspmm.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\storage.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\tensor.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\testing.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\transpose.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\typing.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\utils.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   copying torch_sparse\__init__.py -> build\lib.win-amd64-cpython-311\torch_sparse
#   running egg_info
#   writing torch_sparse.egg-info\PKG-INFO
#   writing dependency_links to torch_sparse.egg-info\dependency_links.txt
#   writing requirements to torch_sparse.egg-info\requires.txt
#   writing top-level names to torch_sparse.egg-info\top_level.txt
#   reading manifest file 'torch_sparse.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files matching '*' found under directory 'third_party\parallel-hashmap\css'
#   warning: no previously-included files matching '*' found under directory 'third_party\parallel-hashmap\html'
#   warning: no previously-included files matching '*' found under directory 'third_party\parallel-hashmap\tests'
#   warning: no previously-included files matching '*' found under directory 'third_party\parallel-hashmap\examples'
#   warning: no previously-included files matching '*' found under directory 'third_party\parallel-hashmap\benchmark'
#   warning: no previously-included files matching '*' found under directory 'test'
#   warning: no previously-included files matching '*' found under directory 'benchmark'
#   adding license file 'LICENSE'
#   writing manifest file 'torch_sparse.egg-info\SOURCES.txt'
#   running build_ext
#   D:\programs\python311\Lib\site-packages\torch\utils\cpp_extension.py:383: UserWarning: Error checking compiler version for cl: [WinError 2] The system cannot find the file specified
#     warnings.warn(f'Error checking compiler version for {compiler}: {error}')
#   D:\programs\python311\Lib\site-packages\torch\utils\cpp_extension.py:414: UserWarning: The detected CUDA version (12.3) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#     warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
#   building 'torch_sparse._convert_cpu' extension
#   creating build\temp.win-amd64-cpython-311
#   creating build\temp.win-amd64-cpython-311\Release
#   creating build\temp.win-amd64-cpython-311\Release\csrc
#   creating build\temp.win-amd64-cpython-311\Release\csrc\cpu
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\convert.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\convert.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_convert_cpu -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   convert.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\cpu\convert_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\cpu\convert_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_convert_cpu -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   convert_cpu.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib /EXPORT:PyInit__convert_cpu build\temp.win-amd64-cpython-311\Release\csrc\convert.obj build\temp.win-amd64-cpython-311\Release\csrc\cpu\convert_cpu.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_convert_cpu.pyd /IMPLIB:build\temp.win-amd64-cpython-311\Release\csrc\_convert_cpu.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library build\temp.win-amd64-cpython-311\Release\csrc\_convert_cpu.lib and object build\temp.win-amd64-cpython-311\Release\csrc\_convert_cpu.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._convert_cuda' extension
#   creating build\temp.win-amd64-cpython-311\Release\csrc\cuda
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\convert.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\convert.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_convert_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   convert.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\cpu\convert_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\cpu\convert_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_convert_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   convert_cpu.cpp
#   "C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\bin\nvcc" -c csrc\cuda\convert_cuda.cu -o build\temp.win-amd64-cpython-311\Release\csrc\cuda\convert_cuda.obj -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" -Xcudafe --diag_suppress=dll_interface_conflict_dllexport_assumed -Xcudafe --diag_suppress=dll_interface_conflict_none_assumed -Xcudafe --diag_suppress=field_without_dll_interface -Xcudafe --diag_suppress=base_class_has_different_dll_interface -Xcompiler /EHsc -Xcompiler /wd4068 -Xcompiler /wd4067 -Xcompiler /wd4624 -Xcompiler /wd4190 -Xcompiler /wd4018 -Xcompiler /wd4275 -Xcompiler /wd4267 -Xcompiler /wd4244 -Xcompiler /wd4251 -Xcompiler /wd4819 -Xcompiler /MD -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -O3 --expt-relaxed-constexpr -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_convert_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_89,code=compute_89 -gencode=arch=compute_89,code=sm_89 -std=c++17 --use-local-env
#   convert_cuda.cu
#   tmpxft_00001ea0_00000000-7_convert_cuda.cudafe1.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib "/LIBPATH:C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\lib\x64" /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib cudart.lib c10_cuda.lib torch_cuda.lib /EXPORT:PyInit__convert_cuda build\temp.win-amd64-cpython-311\Release\csrc\convert.obj build\temp.win-amd64-cpython-311\Release\csrc\cpu\convert_cpu.obj build\temp.win-amd64-cpython-311\Release\csrc\cuda\convert_cuda.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_convert_cuda.pyd /IMPLIB:build\temp.win-amd64-cpython-311\Release\csrc\_convert_cuda.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library build\temp.win-amd64-cpython-311\Release\csrc\_convert_cuda.lib and object build\temp.win-amd64-cpython-311\Release\csrc\_convert_cuda.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._diag_cpu' extension
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\cpu\diag_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\cpu\diag_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_diag_cpu -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   diag_cpu.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\diag.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\diag.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_diag_cpu -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   diag.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib /EXPORT:PyInit__diag_cpu build\temp.win-amd64-cpython-311\Release\csrc\cpu\diag_cpu.obj build\temp.win-amd64-cpython-311\Release\csrc\diag.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_diag_cpu.pyd /IMPLIB:build\temp.win-amd64-cpython-311\Release\csrc\cpu\_diag_cpu.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library build\temp.win-amd64-cpython-311\Release\csrc\cpu\_diag_cpu.lib and object build\temp.win-amd64-cpython-311\Release\csrc\cpu\_diag_cpu.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._diag_cuda' extension
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\cpu\diag_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\cpu\diag_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_diag_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   diag_cpu.cpp
#   "C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\bin\nvcc" -c csrc\cuda\diag_cuda.cu -o build\temp.win-amd64-cpython-311\Release\csrc\cuda\diag_cuda.obj -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" -Xcudafe --diag_suppress=dll_interface_conflict_dllexport_assumed -Xcudafe --diag_suppress=dll_interface_conflict_none_assumed -Xcudafe --diag_suppress=field_without_dll_interface -Xcudafe --diag_suppress=base_class_has_different_dll_interface -Xcompiler /EHsc -Xcompiler /wd4068 -Xcompiler /wd4067 -Xcompiler /wd4624 -Xcompiler /wd4190 -Xcompiler /wd4018 -Xcompiler /wd4275 -Xcompiler /wd4267 -Xcompiler /wd4244 -Xcompiler /wd4251 -Xcompiler /wd4819 -Xcompiler /MD -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -O3 --expt-relaxed-constexpr -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_diag_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_89,code=compute_89 -gencode=arch=compute_89,code=sm_89 -std=c++17 --use-local-env
#   diag_cuda.cu
#   tmpxft_000016ec_00000000-7_diag_cuda.cudafe1.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\diag.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\diag.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_diag_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   diag.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib "/LIBPATH:C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\lib\x64" /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib cudart.lib c10_cuda.lib torch_cuda.lib /EXPORT:PyInit__diag_cuda build\temp.win-amd64-cpython-311\Release\csrc\cpu\diag_cpu.obj build\temp.win-amd64-cpython-311\Release\csrc\cuda\diag_cuda.obj build\temp.win-amd64-cpython-311\Release\csrc\diag.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_diag_cuda.pyd /IMPLIB:build\temp.win-amd64-cpython-311\Release\csrc\cpu\_diag_cuda.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library build\temp.win-amd64-cpython-311\Release\csrc\cpu\_diag_cuda.lib and object build\temp.win-amd64-cpython-311\Release\csrc\cpu\_diag_cuda.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._ego_sample_cpu' extension
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\cpu\ego_sample_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\cpu\ego_sample_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ego_sample_cpu -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   ego_sample_cpu.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\ego_sample.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\ego_sample.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ego_sample_cpu -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   ego_sample.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib /EXPORT:PyInit__ego_sample_cpu build\temp.win-amd64-cpython-311\Release\csrc\cpu\ego_sample_cpu.obj build\temp.win-amd64-cpython-311\Release\csrc\ego_sample.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_ego_sample_cpu.pyd /IMPLIB:build\temp.win-amd64-cpython-311\Release\csrc\cpu\_ego_sample_cpu.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library build\temp.win-amd64-cpython-311\Release\csrc\cpu\_ego_sample_cpu.lib and object build\temp.win-amd64-cpython-311\Release\csrc\cpu\_ego_sample_cpu.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._ego_sample_cuda' extension
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\cpu\ego_sample_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\cpu\ego_sample_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ego_sample_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   ego_sample_cpu.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\ego_sample.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\ego_sample.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ego_sample_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   ego_sample.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib "/LIBPATH:C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\lib\x64" /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib cudart.lib c10_cuda.lib torch_cuda.lib /EXPORT:PyInit__ego_sample_cuda build\temp.win-amd64-cpython-311\Release\csrc\cpu\ego_sample_cpu.obj build\temp.win-amd64-cpython-311\Release\csrc\ego_sample.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_ego_sample_cuda.pyd /IMPLIB:build\temp.win-amd64-cpython-311\Release\csrc\cpu\_ego_sample_cuda.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library build\temp.win-amd64-cpython-311\Release\csrc\cpu\_ego_sample_cuda.lib and object build\temp.win-amd64-cpython-311\Release\csrc\cpu\_ego_sample_cuda.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._hgt_sample_cpu' extension
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\cpu\hgt_sample_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\cpu\hgt_sample_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_hgt_sample_cpu -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   hgt_sample_cpu.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\hgt_sample.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\hgt_sample.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_hgt_sample_cpu -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   hgt_sample.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib /EXPORT:PyInit__hgt_sample_cpu build\temp.win-amd64-cpython-311\Release\csrc\cpu\hgt_sample_cpu.obj build\temp.win-amd64-cpython-311\Release\csrc\hgt_sample.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_hgt_sample_cpu.pyd /IMPLIB:build\temp.win-amd64-cpython-311\Release\csrc\cpu\_hgt_sample_cpu.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library build\temp.win-amd64-cpython-311\Release\csrc\cpu\_hgt_sample_cpu.lib and object build\temp.win-amd64-cpython-311\Release\csrc\cpu\_hgt_sample_cpu.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._hgt_sample_cuda' extension
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\cpu\hgt_sample_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\cpu\hgt_sample_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_hgt_sample_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   hgt_sample_cpu.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-q95l6d72\torch-sparse_68a644811b4c412388bad5253d1777bf\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tpcsrc\hgt_sample.cpp /Fobuild\temp.win-amd64-cpython-311\Release\csrc\hgt_sample.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_hgt_sample_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   hgt_sample.cpp
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib "/LIBPATH:C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\lib\x64" /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib cudart.lib c10_cuda.lib torch_cuda.lib /EXPORT:PyInit__hgt_sample_cuda build\temp.win-amd64-cpython-311\Release\csrc\cpu\hgt_sample_cpu.obj build\temp.win-amd64-cpython-311\Release\csrc\hgt_sample.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_hgt_sample_cuda.pyd /IMPLIB:build\temp.win-amd64-cpython-311\Release\csrc\cpu\_hgt_sample_cuda.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library build\temp.win-amd64-cpython-311\Release\csrc\cpu\_hgt_sample_cuda.lib and object build\temp.win-amd64-cpython-311\Release\csrc\cpu\_hgt_sample_cuda.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._metis_cpu' extension
# ...
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:D:\programs\python311\Lib\site-packages\torch\lib /LIBPATH:D:\programs\python311\libs /LIBPATH:D:\programs\python311 /LIBPATH:D:\programs\python311\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib /EXPORT:PyInit__rw_cpu C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cpu\rw_cpu.obj C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\rw.obj /OUT:build\lib.win-amd64-cpython-311\torch_sparse\_rw_cpu.pyd /IMPLIB:C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cpu\_rw_cpu.lib -s
#   LINK : warning LNK4044: unrecognized option '/s'; ignored
#      Creating library C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cpu\_rw_cpu.lib and object C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cpu\_rw_cpu.exp
#   Generating code
#   Finished generating code
#   building 'torch_sparse._rw_cuda' extension
#   Emitting ninja build file C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\build.ninja...
#   Compiling objects...
#   Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
#   [1/3] cl /showIncludes /nologo /O2 /W3 /GL /DNDEBUG /MD /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" -c C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\csrc\cpu\rw_cpu.cpp /FoC:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cpu\rw_cpu.obj -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_rw_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   [2/3] cl /showIncludes /nologo /O2 /W3 /GL /DNDEBUG /MD /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" -c C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\csrc\rw.cpp /FoC:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\rw.obj -O3 -DAT_PARALLEL_OPENMP /openmp -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_rw_cuda -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
#   cl : Command line warning D9002 : ignoring unknown option '-O3'
#   [3/3] C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\bin\nvcc --generate-dependencies-with-compile --dependency-output C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cuda\rw_cuda.obj.d -std=c++17 --use-local-env -Xcompiler /MD -Xcompiler /wd4819 -Xcompiler /wd4251 -Xcompiler /wd4244 -Xcompiler /wd4267 -Xcompiler /wd4275 -Xcompiler /wd4018 -Xcompiler /wd4190 -Xcompiler /wd4624 -Xcompiler /wd4067 -Xcompiler /wd4068 -Xcompiler /EHsc -Xcudafe --diag_suppress=base_class_has_different_dll_interface -Xcudafe --diag_suppress=field_without_dll_interface -Xcudafe --diag_suppress=dll_interface_conflict_none_assumed -Xcudafe --diag_suppress=dll_interface_conflict_dllexport_assumed -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" -c C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\csrc\cuda\rw_cuda.cu -o C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cuda\rw_cuda.obj -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -O3 --expt-relaxed-constexpr -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_rw_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_89,code=compute_89 -gencode=arch=compute_89,code=sm_89
#   FAILED: C:/Users/adi/AppData/Local/Temp/pip-install-3i4wx3fk/torch-sparse_885d6c22b3ec4ba79348c17ac9275dda/build/temp.win-amd64-cpython-311/Release/csrc/cuda/rw_cuda.obj
#   C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\bin\nvcc --generate-dependencies-with-compile --dependency-output C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cuda\rw_cuda.obj.d -std=c++17 --use-local-env -Xcompiler /MD -Xcompiler /wd4819 -Xcompiler /wd4251 -Xcompiler /wd4244 -Xcompiler /wd4267 -Xcompiler /wd4275 -Xcompiler /wd4018 -Xcompiler /wd4190 -Xcompiler /wd4624 -Xcompiler /wd4067 -Xcompiler /wd4068 -Xcompiler /EHsc -Xcudafe --diag_suppress=base_class_has_different_dll_interface -Xcudafe --diag_suppress=field_without_dll_interface -Xcudafe --diag_suppress=dll_interface_conflict_none_assumed -Xcudafe --diag_suppress=dll_interface_conflict_dllexport_assumed -DWITH_PYTHON -Dtorchsparse_EXPORTS -DWITH_CUDA -Icsrc -IC:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\third_party\parallel-hashmap -ID:\programs\python311\Lib\site-packages\torch\include -ID:\programs\python311\Lib\site-packages\torch\include\torch\csrc\api\include -ID:\programs\python311\Lib\site-packages\torch\include\TH -ID:\programs\python311\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3\include" -ID:\programs\python311\include -ID:\programs\python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.37.32822\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" -c C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\csrc\cuda\rw_cuda.cu -o C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\build\temp.win-amd64-cpython-311\Release\csrc\cuda\rw_cuda.obj -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -O3 --expt-relaxed-constexpr -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_rw_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_89,code=compute_89 -gencode=arch=compute_89,code=sm_89
#   rw_cuda.cu
#
#   tmpxft_0000766c_00000000-7_rw_cuda.cudafe1.cpp
#
#   c1xx: fatal error C1083: Cannot open source file: 'C:\Users\adi\AppData\Local\Temp\tmpxft_0000766c_00000000-7_rw_cuda.cudafe1.cpp': Permission denied
#
#   ninja: build stopped: subcommand failed.
#   Traceback (most recent call last):
#     File "D:\programs\python311\Lib\site-packages\torch\utils\cpp_extension.py", line 2100, in _run_ninja_build
#       subprocess.run(
#     File "D:\programs\python311\Lib\subprocess.py", line 571, in run
#       raise CalledProcessError(retcode, process.args,
#   subprocess.CalledProcessError: Command '['ninja', '-v']' returned non-zero exit status 1.
#
#   The above exception was the direct cause of the following exception:
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\adi\AppData\Local\Temp\pip-install-3i4wx3fk\torch-sparse_885d6c22b3ec4ba79348c17ac9275dda\setup.py", line 147, in <module>
#       setup(
#     File "D:\programs\python311\Lib\site-packages\setuptools\__init__.py", line 103, in setup
#       return distutils.core.setup(**attrs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#              ^^^^^^^^^^^^^^^^^^
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "D:\programs\python311\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#       super().run_command(command)
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "D:\programs\python311\Lib\site-packages\wheel\bdist_wheel.py", line 369, in run
#       self.run_command("build")
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "D:\programs\python311\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#       super().run_command(command)
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#       self.run_command(cmd_name)
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "D:\programs\python311\Lib\site-packages\setuptools\dist.py", line 989, in run_command
#       super().run_command(command)
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "D:\programs\python311\Lib\site-packages\setuptools\command\build_ext.py", line 88, in run
#       _build_ext.run(self)
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 345, in run
#       self.build_extensions()
#     File "D:\programs\python311\Lib\site-packages\torch\utils\cpp_extension.py", line 873, in build_extensions
#       build_ext.build_extensions(self)
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 467, in build_extensions
#       self._build_extensions_serial()
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 493, in _build_extensions_serial
#       self.build_extension(ext)
#     File "D:\programs\python311\Lib\site-packages\setuptools\command\build_ext.py", line 249, in build_extension
#       _build_ext.build_extension(self, ext)
#     File "D:\programs\python311\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 548, in build_extension
#       objects = self.compiler.compile(
#                 ^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\programs\python311\Lib\site-packages\torch\utils\cpp_extension.py", line 845, in win_wrap_ninja_compile
#       _write_ninja_file_and_compile_objects(
#     File "D:\programs\python311\Lib\site-packages\torch\utils\cpp_extension.py", line 1774, in _write_ninja_file_and_compile_objects
#       _run_ninja_build(
#     File "D:\programs\python311\Lib\site-packages\torch\utils\cpp_extension.py", line 2116, in _run_ninja_build
#       raise RuntimeError(message) from e
#   RuntimeError: Error compiling objects for extension
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for torch-sparse
# ERROR: Could not build wheels for torch-sparse, which is required to install pyproject.toml-based projects

# %% [markdown]
# We will now create a function that will help us visualize a graph data.

# %%
def visualize_graph(G, color):
    plt.figure(figsize=(7,7))
    plt.xticks([])
    plt.yticks([])
    nx.draw_networkx(G, pos=nx.spring_layout(G, seed=42), with_labels=False,
                     node_color=color, cmap="Set2")
    plt.show()

# %% [markdown]
# Graph dataset
#
# PyG provides access to a couple of graph datasets. For this notebook, we are going to use that Zachary's karate club network

# %%
from torch_geometric.datasets import KarateClub

dataset = KarateClub()

# %% [markdown]
# Now that we have imported a graph dataset, let's look at some of the properties of a graph dataset. We will look at some of the properties at the level of the dataset and then select a graph in the dataset to explore it's properties.

# %%
print('Dataset properties')
print('==============================================================')
print(f'Dataset: {dataset}') #This prints the name of the dataset
print(f'Number of graphs in the dataset: {len(dataset)}')
print(f'Number of features: {dataset.num_features}') #Number of features each node in the dataset has
print(f'Number of classes: {dataset.num_classes}') #Number of classes that a node can be classified into


#Since we have one graph in the dataset, we will select the graph and explore it's properties

data = dataset[0]
print('Graph properties')
print('==============================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}') #Number of nodes in the graph
print(f'Number of edges: {data.num_edges}') #Number of edges in the graph
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}') # Average number of nodes in the graph
print(f'Contains isolated nodes: {data.has_isolated_nodes()}') #Does the graph contains nodes that are not connected
print(f'Contains self-loops: {data.has_self_loops()}') #Does the graph contains nodes that are linked to themselves
print(f'Is undirected: {data.is_undirected()}') #Is the graph an undirected graph
# Out:
# Dataset properties
# ==============================================================
# Dataset: KarateClub()
# Number of graphs in the dataset: 1
# Number of features: 34
# Number of classes: 4
# Graph properties
# ==============================================================
# Number of nodes: 34
# Number of edges: 156
# Average node degree: 4.59
# Contains isolated nodes: False
# Contains self-loops: False
# Is undirected: True

# %% [markdown]
# Now let's visualize the graph using the function that we created earlier. But first, we will convert the graph to networkx graph

# %%
from torch_geometric.utils import to_networkx

G = to_networkx(data, to_undirected=True)
visualize_graph(G, color=data.y)

# %% [markdown]
# **Implementing a Graph Neural Network**
#
# For this notebook, we will use a simple GNN which is the Graph Convolution Network (GCN) layer. Our GNN is defined by stacking three graph convolution layers, which corresponds to aggregating 3-hop neighborhood information around each node (all nodes up to 3 "hops" away). In addition, the GCNConv layers reduce the node feature dimensionality to  2 , i.e.,  34→4→4→2 . Each GCNConv layer is enhanced by a tanh non-linearity. We then apply a linear layer  which acts as a classifier to map the nodes to 1 out of the 4 possible classes

# %%
import torch
from torch.nn import Linear
from torch_geometric.nn import GCNConv


class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(dataset.num_features, 4)
        self.conv2 = GCNConv(4, 4)
        self.conv3 = GCNConv(4, 2)
        self.classifier = Linear(2, dataset.num_classes)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h = h.tanh()
        h = self.conv2(h, edge_index)
        h = h.tanh()
        h = self.conv3(h, edge_index)
        h = h.tanh()  # Final GNN embedding space.
        
        # Apply a final (linear) classifier.
        out = self.classifier(h)

        return out, h

model = GCN()
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(34, 4)
#   (conv2): GCNConv(4, 4)
#   (conv3): GCNConv(4, 2)
#   (classifier): Linear(in_features=2, out_features=4, bias=True)
# )

# %% [markdown]
# **Training of the Network Model**
#
# To train the network, we will use the **CrossEntropyLoss** for the loss function and **Adam** as the gradient optimizer

# %%
model = GCN()
criterion = torch.nn.CrossEntropyLoss()  #Initialize the CrossEntropyLoss function.
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)  # Initialize the Adam optimizer.

def train(data):
    optimizer.zero_grad()  # Clear gradients.
    out, h = model(data.x, data.edge_index)  # Perform a single forward pass.
    loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    return loss, h

for epoch in range(401):
    loss, h = train(data)
    print(f'Epoch: {epoch}, Loss: {loss}')
# Out:
# Epoch: 0, Loss: 1.414404273033142
# Epoch: 1, Loss: 1.4079036712646484
# Epoch: 2, Loss: 1.4017865657806396
# Epoch: 3, Loss: 1.3959277868270874
# Epoch: 4, Loss: 1.3902204036712646
# Epoch: 5, Loss: 1.3845514059066772
# Epoch: 6, Loss: 1.3788156509399414
# Epoch: 7, Loss: 1.372924566268921
# Epoch: 8, Loss: 1.3668040037155151
# Epoch: 9, Loss: 1.3603920936584473
# Epoch: 10, Loss: 1.3536322116851807
